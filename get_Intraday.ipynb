# %%
# import ssi_fc_trading
from ssi_fc_data import fc_md_client , model
import config
import sys
import datetime
import json
import csv

# %%
client = fc_md_client.MarketDataClient(config)

# %%
print(client.daily_stock_price(config, model.daily_stock_price ('ssi', '17/12/2025', '17/12/2025', 1, 100, 'hose')))
# Out:
# {'data': [{'TradingDate': '17/12/2025', 'PriceChange': '-600', 'PerPriceChange': '-2', 'CeilingPrice': '32350', 'FloorPrice': '28150', 'RefPrice': '30250', 'OpenPrice': '30000', 'HighestPrice': '30100', 'LowestPrice': '29600', 'ClosePrice': '29650', 'AveragePrice': '30100', 'ClosePriceAdjusted': '29650', 'TotalMatchVol': '13669700', 'TotalMatchVal': '408230325000', 'TotalDealVal': '23508050000', 'TotalDealVol': '763000', 'ForeignBuyVolTotal': '339660', 'ForeignCurrentRoom': '1408293287', 'ForeignSellVolTotal': '792949', 'ForeignBuyValTotal': '10150717000', 'ForeignSellValTotal': '23677216750', 'TotalBuyTrade': '0', 'TotalBuyTradeVol': '0', 'TotalSellTrade': '0', 'TotalSellTradeVol': '0', 'NetBuySellVol': '-453289', 'NetBuySellVal': '-13526499750', 'TotalTradedVol': '14432700', 'TotalTradedValue': '431738375000', 'Symbol': 'SSI', 'Time': None}], 'message': 'Success', 'status': 'Success', 'totalRecord': 1}

# %%
print(client.intraday_ohlc(config, model.intraday_ohlc('ssi', '17/12/2025', '17/12/2025', 1, 1, True, 1)))
# Out:
# {'data': [{'Symbol': 'SSI', 'Value': '29950', 'TradingDate': '17/12/2025', 'Time': '09:15:59', 'Open': '30000', 'High': '30100', 'Low': '29800', 'Close': '30000', 'Volume': '440600'}], 'message': 'Success', 'status': 'Success', 'totalRecord': 226}
